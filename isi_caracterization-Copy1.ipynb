# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
##Condición spike --> punto medio inicio fin evento
def to_mean(data):
    return np.array([np.mean([a,b]) for a,b in zip(data[:,0],data[:,1])])

# %%
def get_ISI(events):
    isi = list(map(lambda x,y: y-x, events[:-1],events[1:]))
    return isi

# %%
def plot_ISI(ISI,title,xlim=(10,50),ylim=(10,50),outliers=1):
    plt.title(title+" ("+str(len(ISI))+")")
    plt.plot(ISI[:-outliers],ISI[outliers:],'.',markersize=1)
    plt.plot(ISI,ISI,linewidth=0.3)
    plt.xlabel('ISI_i [s]')
    plt.ylabel('ISI_i+1 [s]')
    plt.show()
    
    plt.title(title+" ("+str(len(ISI))+")")
    plt.xlim(xlim[0],xlim[1])
    plt.ylim(ylim[0],ylim[1])
    plt.plot(ISI[:-1],ISI[1:],'.',markersize=1)
    plt.plot(ISI,ISI,linewidth=0.3)
    plt.xlabel('ISI_i [s]')
    plt.ylabel('ISI_i+1 [s]')
    plt.show()

# %% [markdown]
# # Completos

# %%
data_n1m = np.loadtxt('../24-Jun-2019/24-Jun_N1m-spikes.txt')

print(data_n1m.shape)

#Poner en segundos

data_n1m /= 10000

# data_lp = data_lp[:(data_lp.shape[0]//2)]
# Out:
# (4407, 2)

# %%
mean_evt_n1m = to_mean(data_n1m)
print(mean_evt_n1m.shape)
# Out:
# 0.1203400018 0.12068000179999999
# 0.12298000179999999 0.12339000180000001
# 0.12547000190000002 0.1259300019
# 0.1281200019 0.1286100019
# 0.131340002 0.131800002
# 0.133860002 0.134460002
# 0.136270002 0.137100002
# 0.1398200021 0.1406200021
# 0.1426100021 0.14372000210000002
# 0.1459900022 0.1474800022
# 0.1496600022 0.15172000230000002
# 0.1536600023 0.1565100023
# 0.32507000480000003 0.3260200049
# 0.333640005 0.33544000500000004
# 0.3427100051 0.34448000510000004
# 0.35233000529999997 0.3538300053
# 0.8556800128000001 0.8560200128000001
# 0.8584900127999999 0.8589000128
# 0.8610900128 0.8615700128
# 0.8641700129000001 0.8646400128999999
# 0.8670700129000001 0.8675800129
# 0.869600013 0.870270013
# 0.872250013 0.873330013
# 0.8757900131 0.8767000131000001
# 0.8789600130999999 0.8802100130999999
# 0.8825300132 0.8839700132
# 0.8865900132000001 0.8883300132
# 0.8909100133 0.8928400133
# 0.8951600133 0.8966800133999999
# 1.071140016 1.072290016
# 1.0801900161 1.0819900161
# ...

# %%
# parte = 8
# plt.plot(mean_evt_lp[:parte],np.ones(parte),'.')
# plt.plot(data_lp[:parte,0],np.zeros(parte),'.')
# plt.plot(data_lp[:parte,1],np.zeros(parte),'.')

# %%
ISI_n1m = get_ISI(mean_evt_n1m)

# %%
plt.hist(ISI_n1m,rwidth=0.4,range=(0,0.05))
plt.show()

# %%
plot_ISI(ISI_n1m[:],'N1M',xlim=(-0.05,0.3),ylim=(-0.05,0.3))

# %% [markdown]
# # Ventana1

# %%
data_pd = np.loadtxt('spikes_PD_deriv_ventana.txt')
data_lp = np.loadtxt('spikes_LP_deriv_ventana.txt')

print(data_pd.shape)
print(data_lp.shape)

#Poner en segundos

data_pd /= 10000
data_lp /= 10000

# data_lp = data_lp[:(data_lp.shape[0]//2)]
# Out:
# (1794, 2)
# (1873, 2)

# %%
mean_evt_pd = to_mean(data_pd)
print(mean_evt_pd.shape)
mean_evt_lp = to_mean(data_lp)
print(mean_evt_lp.shape)
# Out:
# (1794,)
# (1873,)

# %%
# parte = 8
# plt.plot(mean_evt_lp[:parte],np.ones(parte),'.')
# plt.plot(data_lp[:parte,0],np.zeros(parte),'.')
# plt.plot(data_lp[:parte,1],np.zeros(parte),'.')

# %%
ISI_pd = get_ISI(mean_evt_pd)
ISI_lp = get_ISI(mean_evt_lp)

# %%
plt.hist(ISI_pd,rwidth=0.4,range=(0,0.05))
plt.show()
plt.hist(ISI_lp,rwidth=0.4,range=(0,0.05))
plt.show()

# %%
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.1),ylim=(0,0.1))
plot_ISI(ISI_lp[:],'LP',xlim=(0,0.1),ylim=(0,0.1))

# %% [markdown]
# # Ventana 2

# %%
data_pd = np.loadtxt('spikes_PD_deriv_ventana2.txt')
data_lp = np.loadtxt('spikes_LP_deriv_ventana2.txt')

print(data_pd.shape)
print(data_lp.shape)

#Poner en segundos

data_pd /= 10000
data_lp /= 10000

# data_lp = data_lp[:(data_lp.shape[0]//2)]
# Out:
# (1687, 2)
# (3464, 2)

# %%
mean_evt_pd = to_mean(data_pd)
print(mean_evt_pd.shape)
mean_evt_lp = to_mean(data_lp)
print(mean_evt_lp.shape)
# Out:
# (1687,)
# (3464,)

# %%
ISI_pd = get_ISI(mean_evt_pd)
ISI_lp = get_ISI(mean_evt_lp)

# %%
plt.hist(ISI_pd,rwidth=0.4,range=(0,0.05))
plt.show()
plt.hist(ISI_lp,rwidth=0.4,range=(0,0.05))
plt.show()

# %%
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.1),ylim=(0,0.1))
plot_ISI(ISI_lp[:],'LP',xlim=(0,0.1),ylim=(0,0.1))

# %% [markdown]
# # Ventana 3

# %%
data_pd = np.loadtxt('spikes_PD_deriv_ventana3.txt')
data_lp = np.loadtxt('spikes_LP_deriv_ventana3.txt')

print(data_pd.shape)
print(data_lp.shape)


#Poner en segundos

data_pd /= 10000
data_lp /= 10000
# data_lp = data_lp[:(data_lp.shape[0]//2)]
# Out:
# (3629, 2)
# (3498, 2)

# %%
mean_evt_pd = to_mean(data_pd)
print(mean_evt_pd.shape)
mean_evt_lp = to_mean(data_lp)
print(mean_evt_lp.shape)
# Out:
# (3629,)
# (3498,)

# %%
ISI_pd = get_ISI(mean_evt_pd)
ISI_lp = get_ISI(mean_evt_lp)

# %%
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.05),ylim=(0,0.05))
plot_ISI(ISI_lp[:],'LP',xlim=(0,0.1),ylim=(0,0.1))

# %% [markdown]
# # Ventana 4

# %%
data_pd = np.loadtxt('spikes_PD_deriv_ventana4.txt')
data_lp = np.loadtxt('spikes_LP_deriv_ventana4.txt')

print(data_pd.shape)
print(data_lp.shape)

#Poner en segundos

data_pd /= 10000
data_lp /= 10000
# data_lp = data_lp[:(data_lp.shape[0]//2)]
# Out:
# (3142, 2)
# (3687, 2)

# %%
mean_evt_pd = to_mean(data_pd)
print(mean_evt_pd.shape)
mean_evt_lp = to_mean(data_lp)
print(mean_evt_lp.shape)
# Out:
# (3142,)
# (3687,)

# %%
ISI_pd = get_ISI(mean_evt_pd)
ISI_lp = get_ISI(mean_evt_lp)

# %%
plt.hist(ISI_pd,rwidth=0.4,range=(0,0.05))
plt.show()
plt.hist(ISI_lp,rwidth=0.4,range=(0,0.05))
plt.show()

# %%
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.1),ylim=(0,0.1))
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.05),ylim=(0,0.05))
plot_ISI(ISI_lp[:],'LP',xlim=(0,0.1),ylim=(0,0.1))

# %% [markdown]
# # Ventana 5

# %%
data_pd = np.loadtxt('spikes_PD_deriv_ventana5.txt')
data_lp = np.loadtxt('spikes_LP_deriv_ventana5.txt')

print(data_pd.shape)
print(data_lp.shape)

#Poner en segundos
data_pd /= 10000
data_lp /= 10000

# data_lp = data_lp[:(data_lp.shape[0]//2)]
# Out:
# (1553, 2)
# (2096, 2)

# %%
mean_evt_pd = to_mean(data_pd)
print(mean_evt_pd.shape)
mean_evt_lp = to_mean(data_lp)
print(mean_evt_lp.shape)
# Out:
# (1553,)
# (2096,)

# %%
ISI_pd = get_ISI(mean_evt_pd)
ISI_lp = get_ISI(mean_evt_lp)

# %%
plt.hist(ISI_pd,rwidth=0.4,range=(0,0.05))
plt.show()
plt.hist(ISI_lp,rwidth=0.4,range=(0,0.05))
plt.show()

# %%
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.05),ylim=(0,0.05))
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.1),ylim=(0,0.1))
plot_ISI(ISI_lp[:],'LP',xlim=(0,0.1),ylim=(0,0.1))

# %% [markdown]
# # Ventana 6

# %%
data_pd = np.loadtxt('spikes_PD_deriv_ventana6.txt')
data_lp = np.loadtxt('spikes_LP_deriv_ventana6.txt')

print(data_pd.shape)
print(data_lp.shape)

# Poner en segundos
data_pd /= 10000
data_lp /= 10000

# data_lp = data_lp[:(data_lp.shape[0]//2)]
# Out:
# (7926, 2)
# (10464, 2)

# %%
mean_evt_pd = to_mean(data_pd)
print(mean_evt_pd.shape)
mean_evt_lp = to_mean(data_lp)
print(mean_evt_lp.shape)
# Out:
# (7926,)
# (10464,)

# %%
ISI_pd = get_ISI(mean_evt_pd)
ISI_lp = get_ISI(mean_evt_lp)

# %%
plt.hist(ISI_pd,rwidth=0.4,range=(0,0.05))
plt.show()
plt.hist(ISI_lp,rwidth=0.4,range=(0,0.05))
plt.show()

# %%
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.1),ylim=(0,0.1))
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.05),ylim=(0,0.05))
plot_ISI(ISI_lp[:],'LP',xlim=(0,0.1),ylim=(0,0.1))

# %% [markdown]
# # Ventana 60 burst (aprox)

# %%
data_pd = np.loadtxt('spikes_PD_deriv_ventana60.txt')
data_lp = np.loadtxt('spikes_LP_deriv_ventana60.txt')

print(data_pd.shape)
print(data_lp.shape)

data_pd /= 10000
data_lp /= 10000

# data_lp = data_lp[:(data_lp.shape[0]//2)]
# Out:
# (396, 2)
# (536, 2)

# %%
mean_evt_pd = to_mean(data_pd)
print(mean_evt_pd.shape)
mean_evt_lp = to_mean(data_lp)
print(mean_evt_lp.shape)
# Out:
# (396,)
# (536,)

# %%
ISI_pd = get_ISI(mean_evt_pd)
ISI_lp = get_ISI(mean_evt_lp)

# %%
plt.hist(ISI_pd,rwidth=0.4,range=(0,0.05))
plt.show()
plt.hist(ISI_lp,rwidth=0.4,range=(0,0.05))
plt.show()

# %%
plot_ISI(ISI_pd[:],'PD',xlim=(0,0.1),ylim=(0,0.1))
plot_ISI(ISI_pd[:],'PD',xlim=(0.01,0.05),ylim=(0.01,0.05))
plot_ISI(ISI_lp[:],'LP',xlim=(0,0.1),ylim=(0,0.1))
plot_ISI(ISI_lp[:],'LP',xlim=(0.01,0.05),ylim=(0.01,0.05))

# %% [markdown]
# # Con datos buenos

# %%
data_pd = np.loadtxt('Control_PD_18h27m02s-15-Feb-2018.txt')
data_lp = np.loadtxt('Control_LP_18h27m02s-15-Feb-2018.txt')

print(data_pd.shape)
print(data_lp.shape)
# Out:
# (9780, 2)
# (12801, 2)

# %%
mean_evt_pd = to_mean(data_pd)
print(mean_evt_pd.shape)
mean_evt_lp = to_mean(data_lp)
print(mean_evt_lp.shape)
# Out:
# (9780,)
# (12801,)

# %%
ISI_pd = get_ISI(mean_evt_pd)
ISI_lp = get_ISI(mean_evt_lp)

# %%
plt.hist(ISI_pd,rwidth=0.4,range=(0,50))
plt.show()
plt.hist(ISI_lp,rwidth=0.4,range=(0,50))
plt.show()

# %%
plot_ISI(ISI_pd,'PD')
plot_ISI(ISI_lp,'LP')
